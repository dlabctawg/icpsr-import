# %% [markdown]
# Now that Brooks has done all the hard work putting together a subsample of the ICPSR data in a delimiter-separated-values file, we can import it into Python to start analyzing it! In this notebook we will see two different Python objects we can use for further text analysis techniques: the Pandas DataFrame and the scikit-learn Document Term Matrix.
#
# The first is a Pandas Dataframe:

# %%
import pandas
#use the pandas read_csv function to read in the delimited file.
df = pandas.read_csv("2pipe/33501-0015-Data-1ksubsamp.w.meta.txt", sep="|") #separator value set to "|"

#see what the dataframe looks like
df
# Out:
#            speechID                                             speech  \
# 0    10419950001379                             In this particular CR?
# 1    10419950005157  Mr. Speaker, I ask unanimous consent that all ...
# 2    10419950005955  Mr. Speaker, I thank the gentleman for yieldin...
# 3    10419950007261  Pursuant to the order of the House of May 12, ...
# 4    10419950008401  Mr. Chairman, this amendment deals with striki...
# 5    10419950010486  Mr. Speaker, if the gentleman will yield furth...
# 6    10419950011475  I was going to say, whether you are talking ab...
# 7    10419950012614                                 Objection is heard
# 8    10419950013345  The gentleman from Colorado is recognized for ...
# 9    10419950015335  Mr. Speaker, I move that the House do now adjo...
# 10   10419950016968  Mr. Chairman, I demand a recorded vote A recor...
# 11   10419950017464  Mr. Chairman, I yield 1\1/2\ minutes to the ge...
# 12   10419950018267            Mr. Chairman, will the gentleman yield?
# 13   10419950018825  The Chair will entertain fifteen 1-minutes on ...
# 14   10419950019108  Mr. Dornan, let me just thank you for all your...
# 15   10419950019240  Mr. Chairman, I move to strike the last word M...
# 16   10419950019526  Mr. Speaker, I would simply like to observe th...
# 17   10419950019875  Pursuant to clause 2 of rule XXIII, the Chair ...
# 18   10419950020433                          That is right, but we----
# 19   10419950020634  The time of the gentleman from Indiana [Mr. Bu...
# 20   10419950020965  Mr. Chairman, my colleague mentioned that ther...
# 21   10419950021345  Mr. Speaker, if I told you that you owed me $5...
# 22   10419950022833  Mr. Chairman, I yield 3 minutes to the gentlew...
# 23   10419950023220  Mr. Speaker, I yield 2 minutes to the gentlema...
# 24   10419950023274  Mr. Speaker, I rise today to join Senator Barb...
# 25   10419950023878  Reclaiming my time, I had an opportunity, I wr...
# 26   10419950026535  Mr. Speaker, I want to thank my friend, the ge...
# 27   10419950028422  Pursuant to the order of the House of today, t...
# 28   10419950029145  Under the Speaker's announced policy of May 12...
# 29   10419950029973  Does the gentleman from New York [Mr. Solomon]...
# ..              ...                                                ...
# 970  11020080024843  Mr. Speaker, last week, I received a notice fr...
# 971  11020080026275  Mr. Speaker, I yield myself such time as I may...
# 972  11020080026936  Mr. Chairman, I just would like to acknowledge...
# 973  11020080029119                          Will the gentleman yield?
# 974  11020080030755  Mr. Speaker, my understanding is it is my oppo...
# 975  11020080032361  In the opinion of the Chair, two-thirds being ...
# 976  11020080033859  Madam Speaker, I rise in opposition to the mot...
# 977  11020080034994  I thank my good friend, the gentleman from Ill...
# 978  11020080035515  That being the case, Mr. Speaker, ``man is man...
# 979  11020080036263  Mr. Speaker, I yield myself such time as I may...
# 980  11020080042247             The Senator from Alabama is recognized
# 981  11020080042887  Under the previous order, the leadership time ...
# 982  11020080042947  Mr. President, I have one very quick point of ...
# 983  11020080043231  1. Concurrent resolution on the budget for fis...
# 984  11020080047359                Without objection, it is so ordered
# 985  11020080047690  Reserving the right to object, we are laying d...
# 986  11020080047890              The Senator from Idaho is recognized.
# 987  11020080048875            The Senator from Virginia is recognized
# 988  11020080049791  I thank my friend, the Senator from Florida, f...
# 989  11020080050744  I send a cloture motion to the desk on a first...
# 990  11020080050955  Mr. President, I have sought recognition to co...
# 991  11020080051653           The Senator from Maryland is recognized.
# 992  11020080052077               Without objection, it is so ordered.
# 993  11020080054411  Without objection, it is so ordered The resolu...
# 994  11020080054728                          The Senator from Maryland
# 995  11020080058634  Mr. President, I wish to go back to the discus...
# 996  11020080058675  The clerk will report the bill by title The as...
# 997  11020080060845  I don't think it will--we will have that happe...
# 998  11020080061811  I yield the floor and suggest the absence of a...
# 999  11020080062746               Without objection, it is so ordered.
#
#      speakerID    date  num_order_within_file                 file  \
# 0       104128  950119                     34   Hcr19ja95-62 1.txt
# 1       104400  950202                     31   Hcr02fe95-56 1.txt
# 2       104128  950203                    257   Hcr03fe95-77 1.txt
# 3       104900  950209                    212   Hcr09fe95-60 1.txt
# 4       104222  950210                      4   Hcr10fe95-60 1.txt
# 5       104275  950216                    159   Hcr16fe95-87 1.txt
# 6       104121  950222                    102   Hcr22fe95-85 1.txt
# 7       104900  950227                      1   Hcr27fe95-62 1.txt
# 8       104374  950228                     24   Hcr28fe95-76 1.txt
# 9       104045  950306                     57   Hcr06mr95-63 1.txt
# 10      104110  950308                     76   Hcr08mr95-80 1.txt
# 11      104325  950309                    157   Hcr09mr95-66 1.txt
# 12      104248  950315                      1   Hcr15mr95-52 1.txt
# 13      104114  950315                    144   Hcr15mr95-76 1.txt
# 14      104133  950315                    427   Hcr15mr95-76 1.txt
# 15      104900  950316                     95   Hcr16mr95-67 1.txt
# 16      104541  950316                      9   Hcr16mr95-83 1.txt
# 17      104900  950321                      1   Hcr21mr95-52 1.txt
# 18      104900  950323                     14  Hcr23mr95-107 1.txt
# 19      104007  950323                      1   Hcr23mr95-70 1.txt
# 20      104320  950323                    315   Hcr23mr95-87 1.txt
# 21      104900  950324                      1  Hcr24mr95-115 1.txt
# 22      104371  950403                      1   Hcr03ap95-54 1.txt
# 23      104053  950404                     14  Hcr04ap95-128 1.txt
# 24      104900  950404                      2  Hcr04ap95-135 1.txt
# 25      104410  950405                      1   Hcr05ap95-98 1.txt
# 26      104900  950515                    167   Hcr15my95-64 1.txt
# 27      104342  950523                     16   Hcr23my95-76 1.txt
# 28      104900  950607                      1   Hcr07jn95-31 1.txt
# 29      104900  950608                    100  Hcr08jn95-137 1.txt
# ..         ...     ...                    ...                  ...
# 970     110290   80714                      2   Hcr14jy08-72 1.txt
# 971     110257   80717                      9   Hcr17jy08-99 1.txt
# 972     110221   80723                    154  Hcr23jy08-106 1.txt
# 973     110305   80730                      9  Hcr30jy08-204 1.txt
# 974     110401   80910                     22   Hcr10se08-83 1.txt
# 975     110900   80917                     12  Hcr17se08-114 1.txt
# 976     110272   80923                     88   Hcr23se08-46 1.txt
# 977     110275   80925                      9  Hcr25se08-295 1.txt
# 978     110107   80926                     11   Hcr26se08-94 1.txt
# 979     110036   80927                      6  Hcr27se08-258 1.txt
# 980     110900   80303                     32   Scr03mr08-64 1.txt
# 981     110900   80306                      1  Scr06mr08-135 1.txt
# 982     110469   80306                     18  Scr06mr08-140 1.txt
# 983     110501   80307                      1   Scr07mr08-47 1.txt
# 984     110900   80410                     13  Scr10ap08-220 1.txt
# 985     110442   80416                     13  Scr16ap08-154 1.txt
# 986     110900   80417                      7  Scr17ap08-169 1.txt
# 987     110900   80429                      6  Scr29ap08-177 1.txt
# 988     110481   80507                     62  Scr07my08-178 1.txt
# 989     110466   80514                     14  Scr14my08-175 1.txt
# 990     110509   80514                      2  Scr14my08-179 1.txt
# 991     110900   80520                      8  Scr20my08-189 1.txt
# 992     110900   80522                      6  Scr22my08-145 1.txt
# 993     110900   80612                      5  Scr12jn08-184 1.txt
# 994     110900   80618                     33  Scr18jn08-205 1.txt
# 995     110439   80721                     11   Scr21jy08-42 1.txt
# 996     110900   80721                      2   Scr21jy08-64 1.txt
# 997     110489   80731                     29  Scr31jy08-138 1.txt
# 998     110484   80909                      2  Scr09se08-193 1.txt
# 999     110900   80916                      4  Scr16se08-252 1.txt
#
#      line_start  line_end         page  char count  word count state  \
# 0           169       170    H344-H345          60          13    IL
# 1           685       727  H1078-H1142        2523         444    UT
# 2          3882      3882  H1168-H1191          39           7    IL
# 3          3986      3989  H1472-H1526          65          11   NaN
# 4            72       153  H1604-H1608        5184         969    MS
# 5          2512      2513  H1862-H1890          89          16    NY
# 6          3603      3630  H2010-H2029        1784         310    ID
# 7            17        18  H2260-H2261          80          15   NaN
# 8           302       307  H2345-H2373         358          69    TX
# 9           840       841  H2663-H2703         111          20    CA
# 10          955       958  H2864-H2872          75          13    GA
# 11         3426      3867  H2923-H2940         171          30    OR
# 12           18        32        H3161         833         136    NJ
# 13         3372      3384  H3227-H3272         807         149    GA
# 14         8987      9020  H3227-H3272        2107         377    IL
# 15         1183      1184  H3281-H3303          57           8   NaN
# 16          492       541  H3318-H3325        3208         574    CA
# 17           14        49  H3333-H3334        1509         237   NaN
# 18           40        41  H3710-H3711          45           9   NaN
# 19           16        34        H3579        1092         187    AL
# 20         3567      3572  H3581-H3631         281          55    OK
# 21           12        14        H3795         107          18   NaN
# 22           18        31        H4043         811         135    TX
# 23           42        42        H4142          36           5    CA
# 24           29        30        H4143          64          11   NaN
# 25           14        14  H4212-H4213          43           7    VA
# 26         3091      3094  H4934-H4956          66          11   NaN
# 27          507       517  H5461-H5468         623         105    PA
# 28           16        19        H5625         108          20   NaN
# 29         2094      2094  H5710-H5734          18           3   NaN
# ..          ...       ...          ...         ...         ...   ...
# 970          12       169         NONE        4628         816    NC
# 971         290       518         NONE        6544        1202    NM
# 972        2543      2552         NONE         493          87    MS
# 973         468       468         NONE          25           4    OH
# 974         611       613         NONE         126          23    VT
# 975         165       166         NONE          83          15   NaN
# 976        2232      2233         NONE          50           9    NY
# 977         376       437         NONE        3788         682    NY
# 978         306       335         NONE        1870         334    FL
# 979         279       300         NONE        1279         208    CA
# 980         831       834         NONE          38           6   NaN
# 981          10        11         NONE          58           9   NaN
# 982         243       252         NONE         573         102    LA
# 983          13      1478         NONE        1286         177    ND
# 984          74        77         NONE          35           6   NaN
# 985         427       433         NONE         387          76    CA
# 986          68        72         NONE          37           6   NaN
# 987         149       149         NONE          39           6   NaN
# 988         951       977         NONE        1484         261    MS
# 989         661       663         NONE         135          24    KY
# 990          70       133         NONE        3984         637    PA
# 991         565       566         NONE          40           6   NaN
# 992         157       158         NONE          36           6   NaN
# 993         107       181         NONE         146          24   NaN
# 994        1023      1026         NONE          25           4   NaN
# 995         292       457         NONE       10489        1910    AZ
# 996          13        17         NONE         157          26   NaN
# 997         437       442         NONE         308          61    NV
# 998         347       347         NONE          53          11    MO
# 999          19        20         NONE          36           6   NaN
#
#                       name chamber district       party
# 0          Cardiss Collins       H        7           D
# 1    Enid Greene Waldholtz       H        2           R
# 2          Cardiss Collins       H        7           D
# 3                  Speaker     NaN      NaN         NaN
# 4              Gene Taylor       H        5           D
# 5       Benjamin A. Gilman       H       20           R
# 6         Michael D. Crapo       H        2           R
# 7                  Speaker     NaN      NaN         NaN
# 8               Joe Barton       H        6           R
# 9       Carlos J. Moorhead       H       27           R
# 10             John Linder       H        4           R
# 11         Elizabeth Furse       H        1           D
# 12       Robert Torricelli       H        9           D
# 13         Saxby Chambliss       H        8           R
# 14       Jerry F. Costello       H       12           D
# 15                 Speaker     NaN      NaN         NaN
# 16           Walter Tucker       H       37           D
# 17                 Speaker     NaN      NaN         NaN
# 18                 Speaker     NaN      NaN         NaN
# 19        Earl F. Hilliard       H        7           D
# 20        Thomas A. Coburn       H        2           R
# 21                 Speaker     NaN      NaN         NaN
# 22             Sam Johnson       H        3           R
# 23           Maxine Waters       H       35           D
# 24                 Speaker     NaN      NaN         NaN
# 25          James P. Moran       H        8           D
# 26                 Speaker     NaN      NaN         NaN
# 27                 Jon Fox       H       13           R
# 28                 Speaker     NaN      NaN         NaN
# 29                 Speaker     NaN      NaN         NaN
# ..                     ...     ...      ...         ...
# 970        Walter B. Jones       H        3  Republican
# 971          Stevan Pearce       H        2  Republican
# 972     Travis W. Childers       H        1  Democratic
# 973             Jim Jordan       H        4  Republican
# 974            Peter Welch       H        1  Democratic
# 975                Speaker     NaN      NaN         NaN
# 976     Carolyn B. Maloney       H       14  Democratic
# 977         Eliot L. Engel       H       17  Democratic
# 978    Lincoln Diaz-Balart       H       21  Republican
# 979            Zoe Lofgren       H       16  Democratic
# 980                Speaker     NaN      NaN         NaN
# 981                Speaker     NaN      NaN         NaN
# 982           David Vitter       S      NaN  Republican
# 983            Kent Conrad       S      NaN  Democratic
# 984                Speaker     NaN      NaN         NaN
# 985          Barbara Boxer       S      NaN  Democratic
# 986                Speaker     NaN      NaN         NaN
# 987                Speaker     NaN      NaN         NaN
# 988        Roger F. Wicker       S      NaN  Republican
# 989        Mitch McConnell       S      NaN  Republican
# 990          Arlen Specter       S      NaN  Republican
# 991                Speaker     NaN      NaN         NaN
# 992                Speaker     NaN      NaN         NaN
# 993                Speaker     NaN      NaN         NaN
# 994                Speaker     NaN      NaN         NaN
# 995                Jon Kyl       S      NaN  Republican
# 996                Speaker     NaN      NaN         NaN
# 997             Harry Reid       S      NaN  Democratic
# 998    Christopher S. Bond       S      NaN  Republican
# 999                Speaker     NaN      NaN         NaN
#
# [1000 rows x 16 columns]

# %% [markdown]
# Easy! We now have a typical table-type dataframe with which most of us are familiar, and we can do any number of splicing, summarizing, or analyses on. For a quick-and-dirty analysis, let's look at the number of words per speech, and find the average number of words per speech, and finally the average number of words per speech for Democrats vs. Republicans.
#
# Note: I'm not using the built in "word count" variable because it looks completely wrong to me. It would be a good idea to check why this is the case.

# %%
###Side cleaning: do some quick cleaning to mark D as Democratic and R as Republican

#df['party'] = df['party'].map({"D": "Democratic", "R": "Republican"})
#print(df['party'])

df['party'] = df['party'].replace('D', 'Democratic')
df['party'] = df['party'].replace('R', 'Republican')

#Now, create a column called "word_count" with each speech's word count, using the split function
## #splitting on white space is the fastest way to get word count
## #but there are more accurate ways to do so, as we'll see below

df['word_count'] = df['speech'].apply(lambda x: len(x.split(' ')))
#check output, including built-in "word count" column which looks wrong to me 
df[['speech', 'word_count', 'word count']]
# Out:
#                                                 speech  word_count  word count
# 0                               In this particular CR?           4          13
# 1    Mr. Speaker, I ask unanimous consent that all ...          25         444
# 2    Mr. Speaker, I thank the gentleman for yieldin...         865           7
# 3    Pursuant to the order of the House of May 12, ...          64          11
# 4    Mr. Chairman, this amendment deals with striki...         382         969
# 5    Mr. Speaker, if the gentleman will yield furth...         132          16
# 6    I was going to say, whether you are talking ab...         450         310
# 7                                   Objection is heard           3          15
# 8    The gentleman from Colorado is recognized for ...           9          69
# 9    Mr. Speaker, I move that the House do now adjo...          29          20
# 10   Mr. Chairman, I demand a recorded vote A recor...          30          13
# 11   Mr. Chairman, I yield 1\1/2\ minutes to the ge...          13          30
# 12             Mr. Chairman, will the gentleman yield?           6         136
# 13   The Chair will entertain fifteen 1-minutes on ...           9         149
# 14   Mr. Dornan, let me just thank you for all your...         111         377
# 15   Mr. Chairman, I move to strike the last word M...         743           8
# 16   Mr. Speaker, I would simply like to observe th...         123         574
# 17   Pursuant to clause 2 of rule XXIII, the Chair ...          68         237
# 18                           That is right, but we----           5           9
# 19   The time of the gentleman from Indiana [Mr. Bu...          11         187
# 20   Mr. Chairman, my colleague mentioned that ther...         120          55
# 21   Mr. Speaker, if I told you that you owed me $5...         638          18
# 22   Mr. Chairman, I yield 3 minutes to the gentlew...          13         135
# 23   Mr. Speaker, I yield 2 minutes to the gentlema...          13           5
# 24   Mr. Speaker, I rise today to join Senator Barb...         610          11
# 25   Reclaiming my time, I had an opportunity, I wr...         145           7
# 26   Mr. Speaker, I want to thank my friend, the ge...         334          11
# 27   Pursuant to the order of the House of today, t...          33         105
# 28   Under the Speaker's announced policy of May 12...          23          20
# 29   Does the gentleman from New York [Mr. Solomon]...          19           3
# ..                                                 ...         ...         ...
# 970  Mr. Speaker, last week, I received a notice fr...         816         816
# 971  Mr. Speaker, I yield myself such time as I may...        1202        1202
# 972  Mr. Chairman, I just would like to acknowledge...          87          87
# 973                          Will the gentleman yield?           4           4
# 974  Mr. Speaker, my understanding is it is my oppo...          23          23
# 975  In the opinion of the Chair, two-thirds being ...          15          15
# 976  Madam Speaker, I rise in opposition to the mot...           9           9
# 977  I thank my good friend, the gentleman from Ill...         682         682
# 978  That being the case, Mr. Speaker, ``man is man...         334         334
# 979  Mr. Speaker, I yield myself such time as I may...         208         208
# 980             The Senator from Alabama is recognized           6           6
# 981  Under the previous order, the leadership time ...           9           9
# 982  Mr. President, I have one very quick point of ...         102         102
# 983  1. Concurrent resolution on the budget for fis...         177         177
# 984                Without objection, it is so ordered           6           6
# 985  Reserving the right to object, we are laying d...          76          76
# 986              The Senator from Idaho is recognized.           6           6
# 987            The Senator from Virginia is recognized           6           6
# 988  I thank my friend, the Senator from Florida, f...         261         261
# 989  I send a cloture motion to the desk on a first...          24          24
# 990  Mr. President, I have sought recognition to co...         637         637
# 991           The Senator from Maryland is recognized.           6           6
# 992               Without objection, it is so ordered.           6           6
# 993  Without objection, it is so ordered The resolu...          24          24
# 994                          The Senator from Maryland           4           4
# 995  Mr. President, I wish to go back to the discus...        1910        1910
# 996  The clerk will report the bill by title The as...          26          26
# 997  I don't think it will--we will have that happe...          61          61
# 998  I yield the floor and suggest the absence of a...          11          11
# 999               Without objection, it is so ordered.           6           6
#
# [1000 rows x 3 columns]

# %% [markdown]
# It passes the sniff test (see rows 0, 7, 994, and 999. Why is "word count" so wrong?). Now we can calculate the total number of words, and the averge number of words per speech, and the average number of words per speech for democrats versus republicans.

# %%
print("Total number of words in database:")
print(df['word_count'].sum())
print()
print("Average number of words per speech")
print(df['word_count'].mean())

#groupby party affiliation
groupby = df.groupby("party")

print("________________________")
print("Average number of words per speech by Party Affiliation:\n")

print(groupby.word_count.mean().sort_values(ascending=False))
# Out:
# Total number of words in database:
# 200604
#
# Average number of words per speech
# 200.604
# ________________________
# Average number of words per speech by Party Affiliation:
#
# party
# Democratic     272.608696
# Republican     223.231771
# L               19.000000
# Independent     14.000000
# Name: word_count, dtype: float64

# %% [markdown]
# Great!
#
# But this type of object is actually quite inefficient for large text-based data.
#
# Another way of storing text-based data is the document-term matrix, and we can do so in sparse format (so don't save the elements that have a value of zero). In Python, we can do this using scikit-learn. The object is called Compressed Sparse Format, and it saves quite a bit of memory.

# %%
#import the function CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

countvec = CountVectorizer()

sklearn_dtm = CountVectorizer().fit_transform(df.speech)

#take a look at the object

####
## The shape of the object shows the number of rows, or documents (first element)
## and the number of unique vocab (second element)
####

print(sklearn_dtm.shape)
####
## We can also see what the object looks like.
## The first element is the document ID, the second element is the vocab ID, and the third
## outside the paranthases, is the word count for each document
print(sklearn_dtm)
# Out:
# (1000, 11389)
#   (0, 5474)	1
#   (0, 10331)	1
#   (0, 7493)	1
#   (0, 2886)	1
#   (1, 6851)	1
#   (1, 9647)	1
#   (1, 1253)	1
#   (1, 10649)	1
#   (1, 2630)	1
#   (1, 10292)	1
#   (1, 957)	1
#   (1, 6613)	1
#   (1, 6558)	1
#   (1, 5064)	1
#   (1, 6177)	1
#   (1, 3053)	1
#   (1, 11263)	1
#   (1, 11181)	1
#   (1, 10412)	1
#   (1, 8866)	1
#   (1, 1050)	1
#   (1, 4219)	1
#   (1, 10297)	1
#   (1, 8653)	1
#   (1, 7242)	1
#   :	:
#   (997, 10855)	1
#   (997, 8729)	1
#   (997, 4995)	1
#   (997, 3755)	1
#   (997, 3208)	1
#   (997, 3592)	2
#   (997, 972)	1
#   (997, 5025)	2
#   (997, 2299)	1
#   (997, 10311)	1
#   (997, 6397)	1
#   (998, 1050)	1
#   (998, 10293)	2
#   (998, 7200)	1
#   (998, 8276)	1
#   (998, 11363)	1
#   (998, 9998)	1
#   (998, 4504)	1
#   (998, 649)	1
#   (999, 5828)	1
#   (999, 11264)	1
#   (999, 5846)	1
#   (999, 9556)	1
#   (999, 7144)	1
#   (999, 7303)	1

# %% [markdown]
# Compare the (approximate) memeory needed for each object, the Pandas dataframe (df) and the sklearn object (sklearn_dtm):

# %%
import sys
df_new = df[['speech']] #to make comparative to the DTM, which is just text
print(sys.getsizeof(df_new))
print(sys.getsizeof(sklearn_dtm))
# Out:
# 1233480
# 56

# %% [markdown]
# The dtm is much much smaller!
#
# We can also easily reproduce what we did above with the Pandas dataframe, using this dtm object, and can do so using a lot less memory.

# %%
import numpy as np
print("Total number of words in the dataframe:")
print(np.sum(sklearn_dtm, axis=0).sum())
print("Average number of words per speech:")
print((np.sum(sklearn_dtm, axis=0).sum())/sklearn_dtm.shape[0])
# Out:
# Total number of words in the dataframe:
# 194295
# Average number of words per speech:
# 194.295

# %% [markdown]
# Note the slight difference in output. Why might this be the case? How could we figure out which speeches are causing the discrepancy?
